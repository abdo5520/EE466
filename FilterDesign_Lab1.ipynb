# %%
import numpy as np
import matplotlib.pyplot as plt
H = np.hstack((np.zeros(20), np.arange(10)/10, np.zeros(20)))
w = np.linspace(-0.5, 0.5, 50)   #parameters are start, end, number of samples in the H vector above
plt.plot(w, H, '.-')
plt.show()

# %%
InversedH = (np.fft.ifft(np.fft.ifftshift(H)))
Shifted_InversedH = np.fft.ifftshift (InversedH)

plt.figure('impulse')
plt.plot(np.real(Shifted_InversedH), '.-')
plt.plot(np.imag(Shifted_InversedH), '.-')
plt.legend(['real','imag'], loc=1)
plt.show()

# %%
Shifted_InversedH
# Out:
# array([ 0.01      +2.22044605e-18j,  0.00845997+4.77875032e-03j,
#         0.00429163+8.15395138e-03j, -0.00127593+9.11438166e-03j,
#        -0.00658099+7.32852081e-03j, -0.01      +3.24919696e-03j,
#        -0.01041738-1.99480177e-03j, -0.0075655 -6.89479190e-03j,
#        -0.00213831-9.97090597e-03j,  0.00435997-1.01875196e-02j,
#         0.01      -7.26542528e-03j,  0.01295275-1.80497117e-03j,
#         0.01202119+4.81896777e-03j,  0.00703755+1.07717124e-02j,
#        -0.00098507+1.42105434e-02j, -0.01      +1.37638192e-02j,
#        -0.01735218+8.91746051e-03j, -0.02038982+2.08284960e-04j,
#        -0.01712081-1.08314022e-02j, -0.00675559-2.19738929e-02j,
#         0.01      -3.07768354e-02j,  0.03098289-3.51351917e-02j,
#         0.0529463 -3.37752273e-02j,  0.07219371-2.65726010e-02j,
#         0.08533562-1.46164054e-02j,  0.09      +0.00000000e+00j,
#         0.08533562+1.46164054e-02j,  0.07219371+2.65726010e-02j,
#         0.0529463 +3.37752273e-02j,  0.03098289+3.51351917e-02j,
#         0.01      +3.07768354e-02j, -0.00675559+2.19738929e-02j,
#        -0.01712081+1.08314022e-02j, -0.02038982-2.08284960e-04j,
#        -0.01735218-8.91746051e-03j, -0.01      -1.37638192e-02j,
#        -0.00098507-1.42105434e-02j,  0.00703755-1.07717124e-02j,
#         0.01202119-4.81896777e-03j,  0.01295275+1.80497117e-03j,
#         0.01      +7.26542528e-03j,  0.00435997+1.01875196e-02j,
#        -0.00213831+9.97090597e-03j, -0.0075655 +6.89479190e-03j,
#        -0.01041738+1.99480177e-03j, -0.01      -3.24919696e-03j,
#        -0.00658099-7.32852081e-03j, -0.00127593-9.11438166e-03j,
#         0.00429163-8.15395138e-03j,  0.00845997-4.77875032e-03j])

# %%
h = Shifted_InversedH
h_fft = np.fft.fftshift(np.abs(np.fft.fft(h, 1024)))
plt.figure('Frequency')
plt.plot(h_fft)
plt.show()
